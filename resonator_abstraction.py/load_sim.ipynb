# %%
import numpy as np
import matplotlib.pyplot as plt
from meep_resonator import *
# Out:
# Using MPI version 4.1, 1 processes

# %%
resonator = RingResonator("simulation_0.5 copy.json")

# %%
resonator.find_resonances(resonance_conf_path="test")
resonator.run_resonance(save_ez=True)
ez_field = resonator.get_waveguide_ez_field()
plt.imshow(ez_field)
# Out:
# Simulation Progress:   0%|          | 0/10 [00:00<?, ?it/s]
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# Simulation Progress: 100%|██████████| 10/10 [00:00<00:00, 24.73it/s]
# 2025-01-24 18:02:46,090 - WARNING - Simulation has not been run! Please run simulation

# %%
resonator.plot_field_result()
