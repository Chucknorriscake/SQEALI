# %%
import numpy as np
import matplotlib.pyplot as plt
from meep_resonator import *
import os

# %%
resonator = RingResonator("conf_overcoupling.json")
resonator.view_sim_region()

# %%
for path in os.listdir():
    if ("simulation" in path) and (".json" in path) and (path != "simulation_sources.json"):
        print(path)
        resonator = RingResonator(path)
        resonator.plot_coupling(slice=59)
        plt.show()
# Out:
# 2025-01-28 16:27:12,041 - INFO - Simulation parameters have been run before and ez field has been loaded!
# simulation_2.8473684210526318.json
# 2025-01-28 16:27:12,151 - INFO - Simulation parameters have been run before and ez field has been loaded!
# simulation_1.6263157894736844.json
# 2025-01-28 16:27:12,263 - INFO - Simulation parameters have been run before and ez field has been loaded!
# simulation_1.168421052631579.json
# 2025-01-28 16:27:12,384 - INFO - Simulation parameters have been run before and ez field has been loaded!
# simulation_0.5578947368421052.json
# 2025-01-28 16:27:12,610 - INFO - Simulation parameters have been run before and ez field has been loaded!
# simulation_0.8631578947368421.json
# 2025-01-28 16:27:12,758 - INFO - Simulation parameters have been run before and ez field has been loaded!
# simulation_2.3894736842105266.json
# 2025-01-28 16:27:12,886 - INFO - Simulation parameters have been run before and ez field has been loaded!
# ...

# %%
resonator = RingResonator("simulation_0.2.json")
resonator.plot_field_result(slice=(0,350))
resonator.plot_coupling(slice=90)
# Out:
# 2025-01-28 15:37:03,341 - INFO - Simulation parameters have been run before and ez field has been loaded!

# %%
resonator = RingResonator("simulation_0.9000000000000001.json")
resonator.plot_coupling(slice=90)
# Out:
# 2025-01-28 15:32:51,559 - INFO - Simulation parameters have been run before and ez field has been loaded!

# %%
resonator = RingResonator("simulation_1.6.json")
resonator.plot_field_result(slice=(0,350))
resonator.plot_coupling(slice=90)
# Out:
# 2025-01-28 15:36:52,922 - INFO - Simulation parameters have been run before and ez field has been loaded!

# %%
resonator = RingResonator("simulation_1.768421052631579.json")
resonator.plot_field_result(slice=(0,350))
resonator.plot_coupling(slice=90)
# Out:
# 2025-01-28 15:36:43,545 - INFO - Simulation parameters have been run before and ez field has been loaded!

# %%
resonator = RingResonator("simulation_1.2842105263157895.json")
resonator.plot_field_result(slice=(0,350))
resonator.plot_coupling(slice=90)
# Out:
# 2025-01-28 15:36:31,160 - INFO - Simulation parameters have been run before and ez field has been loaded!

# %%
resonator = RingResonator("simulation_5.642105263157894.json")
#resonator.plot_coupling(slice=90)
resonator.plot_field_result(slice=(0,350))
# Out:
# 2025-01-28 15:36:20,247 - INFO - Simulation parameters have been run before and ez field has been loaded!

# %%
resonator = RingResonator("simulation_6.610526315789473.json")
#resonator.plot_coupling(slice=90)
resonator.plot_field_result(slice=(0,350))
# Out:
# 2025-01-28 15:36:00,852 - INFO - Simulation parameters have been run before and ez field has been loaded!
