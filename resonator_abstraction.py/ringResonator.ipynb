# %%
from meep_resonator import *
import numpy as np

# %%
resonator = RingResonator(config_file="simulation_1.json")
resonator.run_resonance()
resonator.plot_field_result()
guess = [0.08,0.3, 5]
resonator.plot_coupling(guess)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# [{'useage': 'simulation', 'type': 'mp.ContinuousSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# [{'useage': 'simulation', 'type': 'mp.ContinuousSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000325203 s
# Working in 2D dimensions.
# Computational cell is 24.8125 x 16.8125 x 0 with resolution 16
#      cylinder, center = (0,0,0)
#           radius 2.4, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      cylinder, center = (0,0,0)
#           radius 2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-2.6,0)
#           size (1e+20,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
# time for set_epsilon = 0.158178 s
# -----------
# creating output file "./eps-000000.00.h5"...
# creating output file "./simulation_1.h5"...
# Meep progress: 110.09375/3000.0 = 3.7% done in 4.0s, 105.0s to go
# on time step 3534 (time=110.438), 0.00113192 s/step
# Meep progress: 223.53125/3000.0 = 7.5% done in 8.0s, 99.4s to go
# on time step 7168 (time=224), 0.00110381 s/step
# Meep progress: 355.34375/3000.0 = 11.8% done in 12.0s, 89.3s to go
# on time step 11392 (time=356), 0.000948681 s/step
# Meep progress: 475.0/3000.0 = 15.8% done in 16.0s, 85.1s to go
# on time step 15227 (time=475.844), 0.00104329 s/step
# Meep progress: 596.0/3000.0 = 19.9% done in 20.0s, 80.7s to go
# on time step 19104 (time=597), 0.00103288 s/step
# Meep progress: 724.0/3000.0 = 24.1% done in 24.0s, 75.5s to go
# on time step 23200 (time=725), 0.000976736 s/step
# Meep progress: 853.0/3000.0 = 28.4% done in 28.0s, 70.5s to go
# on time step 27328 (time=854), 0.000969092 s/step
# Meep progress: 972.0/3000.0 = 32.4% done in 32.0s, 66.8s to go
# on time step 31136 (time=973), 0.00105203 s/step
# Meep progress: 1099.875/3000.0 = 36.7% done in 36.0s, 62.2s to go
# on time step 35211 (time=1100.34), 0.000981929 s/step
# Meep progress: 1235.0/3000.0 = 41.2% done in 40.0s, 57.2s to go
# on time step 39552 (time=1236), 0.000922437 s/step
# Meep progress: 1349.0/3000.0 = 45.0% done in 44.0s, 53.9s to go
# on time step 43195 (time=1349.84), 0.00109811 s/step
# Meep progress: 1474.4375/3000.0 = 49.1% done in 48.0s, 49.7s to go
# on time step 47203 (time=1475.09), 0.000998005 s/step
# Meep progress: 1592.78125/3000.0 = 53.1% done in 52.0s, 46.0s to go
# on time step 50989 (time=1593.41), 0.00105653 s/step
# Meep progress: 1716.0/3000.0 = 57.2% done in 56.0s, 41.9s to go
# on time step 54938 (time=1716.81), 0.00101298 s/step
# Meep progress: 1868.0/3000.0 = 62.3% done in 60.0s, 36.4s to go
# on time step 59805 (time=1868.91), 0.000821913 s/step
# Meep progress: 1998.96875/3000.0 = 66.6% done in 64.0s, 32.1s to go
# on time step 63977 (time=1999.28), 0.00095887 s/step
# Meep progress: 2138.0/3000.0 = 71.3% done in 68.1s, 27.4s to go
# on time step 68444 (time=2138.88), 0.000895475 s/step
# Meep progress: 2277.875/3000.0 = 75.9% done in 72.1s, 22.8s to go
# on time step 72907 (time=2278.34), 0.000896421 s/step
# Meep progress: 2418.75/3000.0 = 80.6% done in 76.1s, 18.3s to go
# on time step 77412 (time=2419.12), 0.00088802 s/step
# Meep progress: 2546.0/3000.0 = 84.9% done in 80.1s, 14.3s to go
# on time step 81485 (time=2546.41), 0.000982209 s/step
# Meep progress: 2670.0/3000.0 = 89.0% done in 84.1s, 10.4s to go
# on time step 85446 (time=2670.19), 0.00100997 s/step
# Meep progress: 2787.0/3000.0 = 92.9% done in 88.1s, 6.7s to go
# on time step 89190 (time=2787.19), 0.00106844 s/step
# Meep progress: 2917.0/3000.0 = 97.2% done in 92.1s, 2.6s to go
# on time step 93349 (time=2917.16), 0.00096209 s/step
# run 0 finished at t = 3000.0 (96000 timesteps)

# %%
resonator = RingResonator(config_file="simulation_2.json")
resonator.run_resonance()
resonator.plot_field_result()
guess = [0.08,0.3, 5]
resonator.plot_coupling(guess)
# Out:
# [{'useage': 'simulation', 'type': 'mp.ContinuousSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# [{'useage': 'simulation', 'type': 'mp.ContinuousSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000225067 s
# Working in 2D dimensions.
# Computational cell is 25 x 17 x 0 with resolution 16
#      cylinder, center = (0,0,0)
#           radius 2.5, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      cylinder, center = (0,0,0)
#           radius 2.1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-2.7,0)
#           size (1e+20,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
# time for set_epsilon = 0.155832 s
# -----------
# creating output file "./eps-000000.00.h5"...
# creating output file "./simulation_2.h5"...
# Meep progress: 129.0/3000.0 = 4.3% done in 4.0s, 89.0s to go
# on time step 4149 (time=129.656), 0.000964148 s/step
# Meep progress: 263.6875/3000.0 = 8.8% done in 8.0s, 83.0s to go
# on time step 8448 (time=264), 0.000932377 s/step
# Meep progress: 391.09375/3000.0 = 13.0% done in 12.0s, 80.1s to go
# on time step 12544 (time=392), 0.00097841 s/step
# Meep progress: 501.6875/3000.0 = 16.7% done in 16.0s, 79.7s to go
# on time step 16089 (time=502.781), 0.0011286 s/step
# Meep progress: 634.5625/3000.0 = 21.2% done in 20.0s, 74.6s to go
# on time step 20334 (time=635.438), 0.000942299 s/step
# Meep progress: 764.65625/3000.0 = 25.5% done in 24.0s, 70.2s to go
# on time step 24503 (time=765.719), 0.000959538 s/step
# Meep progress: 904.75/3000.0 = 30.2% done in 28.0s, 64.8s to go
# on time step 28992 (time=906), 0.000893044 s/step
# Meep progress: 1041.8125/3000.0 = 34.7% done in 32.0s, 60.2s to go
# on time step 33383 (time=1043.22), 0.000910975 s/step
# Meep progress: 1189.0625/3000.0 = 39.6% done in 36.0s, 54.8s to go
# on time step 38112 (time=1191), 0.000847279 s/step
# Meep progress: 1318.0/3000.0 = 43.9% done in 40.0s, 51.1s to go
# on time step 42237 (time=1319.91), 0.000969784 s/step
# Meep progress: 1456.28125/3000.0 = 48.5% done in 44.0s, 46.7s to go
# on time step 46656 (time=1458), 0.000907082 s/step
# Meep progress: 1583.25/3000.0 = 52.8% done in 48.0s, 43.0s to go
# on time step 50705 (time=1584.53), 0.000987959 s/step
# Meep progress: 1706.0/3000.0 = 56.9% done in 52.0s, 39.5s to go
# on time step 54650 (time=1707.81), 0.00101403 s/step
# Meep progress: 1838.0/3000.0 = 61.3% done in 56.0s, 35.4s to go
# on time step 58868 (time=1839.62), 0.000948398 s/step
# Meep progress: 1982.0/3000.0 = 66.1% done in 60.0s, 30.8s to go
# on time step 63475 (time=1983.59), 0.00086838 s/step
# Meep progress: 2125.0/3000.0 = 70.8% done in 64.0s, 26.4s to go
# on time step 68044 (time=2126.38), 0.000875491 s/step
# Meep progress: 2269.0/3000.0 = 75.6% done in 68.0s, 21.9s to go
# on time step 72652 (time=2270.38), 0.000868093 s/step
# Meep progress: 2419.6875/3000.0 = 80.7% done in 72.0s, 17.3s to go
# on time step 77472 (time=2421), 0.000831448 s/step
# Meep progress: 2563.0/3000.0 = 85.4% done in 76.0s, 13.0s to go
# on time step 82058 (time=2564.31), 0.000872363 s/step
# Meep progress: 2703.15625/3000.0 = 90.1% done in 80.0s, 8.8s to go
# on time step 86531 (time=2704.09), 0.000894464 s/step
# Meep progress: 2815.0/3000.0 = 93.8% done in 84.1s, 5.5s to go
# on time step 90112 (time=2816), 0.00111824 s/step
# Meep progress: 2951.0/3000.0 = 98.4% done in 88.1s, 1.5s to go
# on time step 94475 (time=2952.34), 0.000916953 s/step
# run 0 finished at t = 3000.0 (96000 timesteps)

# %%
wavelengths = np.linspace(1.5,2.5,2)
for wavelength in wavelengths:
    resonator = RingResonator(config_file="conf_overcoupling.json")
    resonator.base_vars["wavelength"] = wavelength
    resonator.run(resonator.find_resonances, resonance_conf_path="simulation_{}.json".format(wavelength)) 
    
    #resonator.find_resonances(resonance_conf_path="simulation_{}.json".format(wavelength))
# Out:
# 2025-01-23 12:30:08,907 - INFO - Starting target function: find_resonances
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# [{'usage': 'harminv', 'type': 'mp.GaussianSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000260115 s
# Working in 2D dimensions.
# [{'usage': 'harminv', 'type': 'mp.GaussianSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# Computational cell is 24.8125 x 16.8125 x 0 with resolution 16
#      cylinder, center = (0,0,0)
#           radius 2.4, height 1e+20, axis (0, 0, 1)
# 2025-01-23 12:30:08,952 - INFO - Starting target function: find_resonances
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      -----------
# Initializing structure...
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# time for choose_chunkdivision = 0.00027585 s
# cylinder
# Working in 2D dimensions.
# , center = (0,0,0)
#           radius 2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
# Computational cell is 24.8125 x 16.8125 x 0 with resolution 16
#           blockcylinder, center = (0,0,0)
# , center = (0,-2.6,0)
#           size (1e+20,0.4,1e+20)
#           radius 2.4, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#           axes (1,0,0), (0,1,0), (0,0,1)
#                dielectric constant epsilon diagonal = (3.24,3.24,3.24)
# cylinder, center = (0,0,0)
# time for set_epsilon = 0.228258 s
# -----------
#           radius 2, height 1e+20, axis (0, 0, 1)
# creating output file "./eps-000000.00.h5"...
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-2.6,0)
#           size (1e+20,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
# time for set_epsilon = 0.229651 s
# -----------
# creating output file "./eps-000000.00.h5"...
# Meep progress: 72.65625/3050.0 = 2.4% done in 4.0s, 163.9s to go
# on time step 2342 (time=73.1875), 0.00171035 s/step
# Meep progress: 77.96875/3050.0 = 2.6% done in 4.0s, 152.5s to go
# on time step 2523 (time=78.8438), 0.0015871 s/step
# Meep progress: 141.8125/3050.0 = 4.6% done in 8.0s, 164.1s to go
# on time step 4572 (time=142.875), 0.00179378 s/step
# Meep progress: 144.5625/3050.0 = 4.7% done in 8.0s, 161.0s to go
# on time step 4656 (time=145.5), 0.00187579 s/step
# Meep progress: 218.375/3050.0 = 7.2% done in 12.0s, 155.7s to go
# on time step 7042 (time=220.062), 0.00162202 s/step
# Meep progress: 222.46875/3050.0 = 7.3% done in 12.0s, 152.6s to go
# on time step 7148 (time=223.375), 0.00160542 s/step
# Meep progress: 299.65625/3050.0 = 9.8% done in 16.0s, 147.0s to go
# on time step 9614 (time=300.438), 0.00155765 s/step
# Meep progress: 300.4375/3050.0 = 9.9% done in 16.0s, 146.5s to go
# on time step 9659 (time=301.844), 0.00159305 s/step
# Meep progress: 373.53125/3050.0 = 12.2% done in 20.0s, 143.4s to go
# on time step 12023 (time=375.719), 0.00166059 s/step
# Meep progress: 377.03125/3050.0 = 12.4% done in 20.0s, 141.9s to go
# on time step 12108 (time=378.375), 0.00163352 s/step
# Meep progress: 456.6875/3050.0 = 15.0% done in 24.0s, 136.4s to go
# on time step 14695 (time=459.219), 0.00149754 s/step
# Meep progress: 459.4375/3050.0 = 15.1% done in 24.0s, 135.4s to go
# on time step 14749 (time=460.906), 0.0015149 s/step
# Meep progress: 541.1875/3050.0 = 17.7% done in 28.0s, 129.9s to go
# on time step 17401 (time=543.781), 0.00147849 s/step
# Meep progress: 546.625/3050.0 = 17.9% done in 28.0s, 128.3s to go
# on time step 17561 (time=548.781), 0.00142283 s/step
# Meep progress: 628.0625/3050.0 = 20.6% done in 32.0s, 123.5s to go
# on time step 20193 (time=631.031), 0.00143301 s/step
# Meep progress: 635.5/3050.0 = 20.8% done in 32.0s, 121.7s to go
# on time step 20393 (time=637.281), 0.00141442 s/step
# Meep progress: 714.21875/3050.0 = 23.4% done in 36.0s, 117.8s to go
# on time step 22944 (time=717), 0.00145435 s/step
# Meep progress: 720.625/3050.0 = 23.6% done in 36.0s, 116.4s to go
# on time step 23130 (time=722.812), 0.00146258 s/step
# Meep progress: 792.875/3050.0 = 26.0% done in 40.0s, 113.9s to go
# on time step 25429 (time=794.656), 0.00161102 s/step
# Meep progress: 791.25/3050.0 = 25.9% done in 40.0s, 114.3s to go
# on time step 25413 (time=794.156), 0.00175217 s/step
# Meep progress: 860.3125/3050.0 = 28.2% done in 44.0s, 112.1s to go
# on time step 27623 (time=863.219), 0.00182379 s/step
# Meep progress: 862.625/3050.0 = 28.3% done in 44.0s, 111.6s to go
# on time step 27674 (time=864.812), 0.00176969 s/step
# Meep progress: 925.75/3050.0 = 30.4% done in 48.0s, 110.2s to go
# on time step 29673 (time=927.281), 0.00195176 s/step
# Meep progress: 923.8125/3050.0 = 30.3% done in 48.0s, 110.6s to go
# on time step 29617 (time=925.531), 0.00206302 s/step
# Meep progress: 996.21875/3050.0 = 32.7% done in 52.0s, 107.3s to go
# on time step 31996 (time=999.875), 0.00172233 s/step
# Meep progress: 1002.84375/3050.0 = 32.9% done in 52.0s, 106.2s to go
# on time step 32226 (time=1007.06), 0.0015338 s/step
# Meep progress: 1079.34375/3050.0 = 35.4% done in 56.0s, 102.3s to go
# on time step 34657 (time=1083.03), 0.00150334 s/step
# Meep progress: 1087.625/3050.0 = 35.7% done in 56.0s, 101.1s to go
# on time step 34934 (time=1091.69), 0.00147711 s/step
# Meep progress: 1164.53125/3050.0 = 38.2% done in 60.0s, 97.2s to go
# on time step 37402 (time=1168.81), 0.00145819 s/step
# Meep progress: 1174.21875/3050.0 = 38.5% done in 60.0s, 95.9s to go
# on time step 37732 (time=1179.12), 0.00143506 s/step
# Meep progress: 1247.28125/3050.0 = 40.9% done in 64.0s, 92.6s to go
# on time step 40059 (time=1251.84), 0.00150557 s/step
# Meep progress: 1257.9375/3050.0 = 41.2% done in 64.0s, 91.2s to go
# on time step 40424 (time=1263.25), 0.00148628 s/step
# Meep progress: 1332.28125/3050.0 = 43.7% done in 68.0s, 87.7s to go
# on time step 42744 (time=1335.75), 0.00149019 s/step
# Meep progress: 1341.71875/3050.0 = 44.0% done in 68.0s, 86.6s to go
# on time step 43109 (time=1347.16), 0.00149285 s/step
# Meep progress: 1410.46875/3050.0 = 46.2% done in 72.1s, 83.8s to go
# on time step 45286 (time=1415.19), 0.00157378 s/step
# Meep progress: 1424.28125/3050.0 = 46.7% done in 72.0s, 82.2s to go
# on time step 45738 (time=1429.31), 0.00152206 s/step
# Meep progress: 1493.875/3050.0 = 49.0% done in 76.1s, 79.2s to go
# on time step 47956 (time=1498.62), 0.00149823 s/step
# Meep progress: 1506.46875/3050.0 = 49.4% done in 76.1s, 77.9s to go
# on time step 48394 (time=1512.31), 0.00150839 s/step
# Meep progress: 1570.8125/3050.0 = 51.5% done in 80.1s, 75.4s to go
# on time step 50431 (time=1575.97), 0.00161626 s/step
# Meep progress: 1585.15625/3050.0 = 52.0% done in 80.1s, 74.0s to go
# on time step 50976 (time=1593), 0.00154952 s/step
# Meep progress: 1632.53125/3050.0 = 53.5% done in 84.1s, 73.0s to go
# on time step 52355 (time=1636.09), 0.00208085 s/step
# Meep progress: 1640.21875/3050.0 = 53.8% done in 84.1s, 72.2s to go
# on time step 52670 (time=1645.94), 0.00236475 s/step
# Meep progress: 1708.90625/3050.0 = 56.0% done in 88.1s, 69.1s to go
# on time step 54849 (time=1714.03), 0.00160387 s/step
# Meep progress: 1721.15625/3050.0 = 56.4% done in 88.1s, 68.0s to go
# on time step 55359 (time=1729.97), 0.00148792 s/step
# Meep progress: 1792.0625/3050.0 = 58.8% done in 92.1s, 64.6s to go
# on time step 57522 (time=1797.56), 0.00149655 s/step
# Meep progress: 1811.09375/3050.0 = 59.4% done in 92.1s, 63.0s to go
# on time step 58250 (time=1820.31), 0.00138414 s/step
# Meep progress: 1873.71875/3050.0 = 61.4% done in 96.1s, 60.3s to go
# on time step 60123 (time=1878.84), 0.00153907 s/step
# Meep progress: 1897.46875/3050.0 = 62.2% done in 96.1s, 58.3s to go
# on time step 60988 (time=1905.88), 0.00146124 s/step
# Meep progress: 1957.46875/3050.0 = 64.2% done in 100.1s, 55.9s to go
# on time step 62787 (time=1962.09), 0.00150266 s/step
# Meep progress: 1980.40625/3050.0 = 64.9% done in 100.1s, 54.0s to go
# on time step 63590 (time=1987.19), 0.00153944 s/step
# Meep progress: 2033.03125/3050.0 = 66.7% done in 104.1s, 52.1s to go
# on time step 65307 (time=2040.84), 0.00158888 s/step
# Meep progress: 2061.8125/3050.0 = 67.6% done in 104.1s, 49.9s to go
# on time step 66270 (time=2070.94), 0.00149271 s/step
# Meep progress: 2118.40625/3050.0 = 69.5% done in 108.1s, 47.5s to go
# on time step 68054 (time=2126.69), 0.00145736 s/step
# Meep progress: 2148.53125/3050.0 = 70.4% done in 108.1s, 45.3s to go
# on time step 69002 (time=2156.31), 0.00146541 s/step
# Meep progress: 2208.46875/3050.0 = 72.4% done in 112.1s, 42.7s to go
# on time step 70945 (time=2217.03), 0.00138388 s/step
# Meep progress: 2237.0625/3050.0 = 73.3% done in 112.1s, 40.7s to go
# on time step 71857 (time=2245.53), 0.00140131 s/step
# Meep progress: 2283.15625/3050.0 = 74.9% done in 116.1s, 39.0s to go
# on time step 73305 (time=2290.78), 0.00169503 s/step
# Meep progress: 2312.15625/3050.0 = 75.8% done in 116.1s, 37.0s to go
# on time step 74347 (time=2323.34), 0.00160662 s/step
# Meep progress: 2364.1875/3050.0 = 77.5% done in 120.1s, 34.8s to go
# on time step 75936 (time=2373), 0.00152217 s/step
# Meep progress: 2394.0/3050.0 = 78.5% done in 120.1s, 32.9s to go
# on time step 76946 (time=2404.56), 0.00154005 s/step
# Meep progress: 2447.3125/3050.0 = 80.2% done in 124.1s, 30.6s to go
# on time step 78587 (time=2455.84), 0.00150941 s/step
# Meep progress: 2476.375/3050.0 = 81.2% done in 124.1s, 28.7s to go
# on time step 79551 (time=2485.97), 0.00153778 s/step
# Meep progress: 2526.6875/3050.0 = 82.8% done in 128.1s, 26.5s to go
# on time step 81173 (time=2536.66), 0.00154724 s/step
# Meep progress: 2561.09375/3050.0 = 84.0% done in 128.1s, 24.4s to go
# on time step 82298 (time=2571.81), 0.00145659 s/step
# Meep progress: 2608.15625/3050.0 = 85.5% done in 132.1s, 22.4s to go
# on time step 83703 (time=2615.72), 0.00158112 s/step
# Meep progress: 2642.3125/3050.0 = 86.6% done in 132.1s, 20.4s to go
# on time step 84813 (time=2650.41), 0.00159183 s/step
# Meep progress: 2683.53125/3050.0 = 88.0% done in 136.1s, 18.6s to go
# on time step 86159 (time=2692.47), 0.00162869 s/step
# Meep progress: 2715.53125/3050.0 = 89.0% done in 136.1s, 16.8s to go
# on time step 87267 (time=2727.09), 0.00163007 s/step
# Meep progress: 2763.09375/3050.0 = 90.6% done in 140.1s, 14.5s to go
# on time step 88716 (time=2772.38), 0.00156576 s/step
# Meep progress: 2795.6875/3050.0 = 91.7% done in 140.1s, 12.7s to go
# on time step 89818 (time=2806.81), 0.00156808 s/step
# Meep progress: 2842.71875/3050.0 = 93.2% done in 144.1s, 10.5s to go
# on time step 91333 (time=2854.16), 0.00152921 s/step
# Meep progress: 2876.84375/3050.0 = 94.3% done in 144.1s, 8.7s to go
# on time step 92488 (time=2890.25), 0.00150053 s/step
# Meep progress: 2925.5625/3050.0 = 95.9% done in 148.1s, 6.3s to go
# on time step 93815 (time=2931.72), 0.00161819 s/step
# Meep progress: 2954.40625/3050.0 = 96.9% done in 148.1s, 4.8s to go
# on time step 94755 (time=2961.09), 0.00176892 s/step
# Meep progress: 2973.59375/3050.0 = 97.5% done in 152.1s, 3.9s to go
# on time step 95385 (time=2980.78), 0.00255371 s/step
# Meep progress: 3003.0625/3050.0 = 98.5% done in 152.1s, 2.4s to go
# on time step 96382 (time=3011.94), 0.00246478 s/step
# Meep progress: 3023.71875/3050.0 = 99.1% done in 156.1s, 1.4s to go
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# on time step 96993 (time=3031.03), 0.00309482 s/step

# %%
wavelengths = np.linspace(1.5,2.5,2)
for wavelength in wavelengths:
    resonator = RingResonator(config_file="conf_overcoupling.json")
    resonator.base_vars["wavelength"] = wavelength
    #resonator.run(resonator.find_resonances, resonance_conf_path="simulation_{}.json".format(wavelength)) 
    
    resonator.find_resonances(resonance_conf_path="simulation_{}.json".format(wavelength))
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# [{'usage': 'harminv', 'type': 'mp.GaussianSource', 'component': 'mp.Ez', 'center_x': '-sx/2 + padding/2 +0.5', 'center_y': 'waveguide_xpos', 'center_z': '0', 'size_x': '0', 'size_y': '0.5*ring_width', 'size_z': '0'}]
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000291824 s
# Working in 2D dimensions.
# Computational cell is 24.8125 x 16.8125 x 0 with resolution 16
#      cylinder, center = (0,0,0)
#           radius 2.4, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
#      cylinder, center = (0,0,0)
#           radius 2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,-2.6,0)
#           size (1e+20,0.4,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.24,3.24,3.24)
# time for set_epsilon = 0.190108 s
# -----------
# creating output file "./eps-000000.00.h5"...
# Meep progress: 48.25/3050.0 = 1.6% done in 4.0s, 249.1s to go
# on time step 1566 (time=48.9375), 0.00255524 s/step
# Meep progress: 94.6875/3050.0 = 3.1% done in 9.0s, 279.6s to go
# on time step 3030 (time=94.6875), 0.00334128 s/step
# Meep progress: 197.5/3050.0 = 6.5% done in 13.0s, 187.2s to go
# on time step 6322 (time=197.562), 0.00121529 s/step
# Meep progress: 353.0625/3050.0 = 11.6% done in 17.0s, 129.5s to go
# on time step 11302 (time=353.188), 0.000803272 s/step
# Meep progress: 512.6875/3050.0 = 16.8% done in 21.0s, 103.7s to go
# on time step 16412 (time=512.875), 0.00078289 s/step
# Meep progress: 683.4375/3050.0 = 22.4% done in 25.0s, 86.4s to go
# on time step 21879 (time=683.719), 0.000731981 s/step
# Meep progress: 856.46875/3050.0 = 28.1% done in 29.0s, 74.2s to go
# on time step 27418 (time=856.812), 0.000722157 s/step
# Meep progress: 1016.875/3050.0 = 33.3% done in 33.0s, 65.9s to go
# on time step 32552 (time=1017.25), 0.000779177 s/step
# Meep progress: 1179.0625/3050.0 = 38.7% done in 37.0s, 58.6s to go
# on time step 37742 (time=1179.44), 0.000770798 s/step
# Meep progress: 1345.0/3050.0 = 44.1% done in 41.0s, 51.9s to go
# on time step 43053 (time=1345.41), 0.000753253 s/step
# Meep progress: 1508.5/3050.0 = 49.5% done in 45.0s, 45.9s to go
# on time step 48289 (time=1509.03), 0.000763954 s/step
# Meep progress: 1666.5625/3050.0 = 54.6% done in 49.0s, 40.6s to go
# on time step 53343 (time=1666.97), 0.000791517 s/step
# Meep progress: 1844.78125/3050.0 = 60.5% done in 53.0s, 34.6s to go
# on time step 59041 (time=1845.03), 0.000702208 s/step
# Meep progress: 2015.25/3050.0 = 66.1% done in 57.0s, 29.2s to go
# on time step 64500 (time=2015.62), 0.000732838 s/step
# Meep progress: 2173.0625/3050.0 = 71.2% done in 61.0s, 24.6s to go
# on time step 69552 (time=2173.5), 0.000791958 s/step
# Meep progress: 2322.28125/3050.0 = 76.1% done in 65.0s, 20.4s to go
# on time step 74331 (time=2322.84), 0.000837099 s/step
# 2025-01-23 12:32:46,942 - INFO - Resonances detected: []
# 2025-01-23 12:32:46,944 - ERROR - Error finding resonances: max() arg is an empty sequence
# 2025-01-23 12:32:46,944 - INFO - Target function find_resonances completed successfully.
# run 0 finished at t = 3050.0 (97600 timesteps)
# 2025-01-23 12:32:48,791 - INFO - Resonances detected: []
# 2025-01-23 12:32:48,792 - ERROR - Error finding resonances: max() arg is an empty sequence
# 2025-01-23 12:32:48,799 - INFO - Target function find_resonances completed successfully.
# harminv0:, frequency, imag. freq., Q, |amp|, amplitude, error
# run 0 finished at t = 3050.0 (97600 timesteps)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 resonator.base_vars["wavelength"] = wavelength
#       5 #resonator.run(resonator.find_resonances, resonance_conf_path="simulation_{}.json".format(wavelength))
# ----> 7 resonator.find_resonances(resonance_conf_path="simulation_{}.json".format(wavelength))
#
# File ~/Resonator/resonator_abstraction.py/meep_resonator.py:336, in RingResonator.find_resonances(self, resonance_conf_path)
#     334 self.sim.reset_meep()
#     335 # Run the simulation and collect resonance data
# --> 336 self.sim.run(
#     337     mp.at_beginning(mp.output_epsilon),
#     338     mp.after_sources(h),
#     339     until_after_sources=self.runtime
#     340 )
#     342 # Log the detected resonances
#     343 logger.info(f"Resonances detected: {h.modes}")
#
# File ~/meep/envs/mp/lib/python3.8/site-packages/meep/simulation.py:4534, in Simulation.run(self, *step_funcs, **kwargs)
#    4531     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4533 if until_after_sources is not None:
# -> 4534     self._run_sources_until(until_after_sources, step_funcs)
#    4535 elif until is not None:
#    4536     self._run_until(until, step_funcs)
#
# File ~/meep/envs/mp/lib/python3.8/site-packages/meep/simulation.py:2874, in Simulation._run_sources_until(self, cond, step_funcs)
#    2870             return cond[i](sim) and sim.round_time() >= ts
#    2872         new_conds.append(f)
# -> 2874 self._run_until(new_conds, step_funcs)
#
# File ~/meep/envs/mp/lib/python3.8/site-packages/meep/simulation.py:2832, in Simulation._run_until(self, cond, step_funcs)
#    2830     for func in step_funcs:
#    2831         _eval_step_func(self, func, "step")
# -> 2832     self.fields.step()
#    2834 # Translating the recursive scheme version of run-until into an iterative version
#    2835 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2836 # be the same as scheme.
#    2837 for func in step_funcs:
#
# File ~/meep/envs/mp/lib/python3.8/site-packages/meep/__init__.py:3041, in fields.step(self)
#    3040 def step(self):
# -> 3041     return _meep.fields_step(self)
#
# KeyboardInterrupt:
